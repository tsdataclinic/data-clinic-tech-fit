# %% [markdown]
# # Basic data visualizations and manipulations

# %%
import seaborn as sns
import os
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

sns.set(
    style='whitegrid',
    font_scale=1,
    rc={"axes.spines.top":False,"axes.spines.right":False,"lines.linewidth": 2.5,'lines.markersize': 10},
    color_codes=False,
    palette=sns.color_palette(['#27a3aa','#f76d23','#70d6e3','#ffbb31','#b1c96d','#cce18a','#1c4c5d','#787642'])
)

ROOT_DIR = "/technical_test"

# %%
os.chdir(ROOT_DIR)

# %% [markdown]
# # Geospatial Visualization

# %%
gdf = gpd.read_file("data/processed/area_median_income_dataset_pumas_ma.geojson",drive="GeoJSON")

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 23 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   STATEFP10                                                          52 non-null     object
#  1   PUMACE10                                                           52 non-null     object
#  2   GEOID10                                                            52 non-null     object
#  3   NAMELSAD10                                                         52 non-null     object
#  4   MTFCC10                                                            52 non-null     object
#  5   FUNCSTAT10                                                         52 non-null     object
#  6   ALAND10                                                            52 non-null     int64
#  7   AWATER10                                                           52 non-null     int64
#  8   INTPTLAT10                                                         52 non-null     object
#  9   INTPTLON10                                                         52 non-null     object
#  10  state                                                              52 non-null     int64
#  11  puma                                                               52 non-null     int64
#  12  name                                                               52 non-null     object
#  13  estimated_area_median_income_householder_age_15_to_24_years        52 non-null     int64
#  14  margin_of_error_area_median_income_householder_age_15_to_24_years  52 non-null     int64
#  15  estimated_area_median_income_householder_age_25_to_44_years        52 non-null     int64
#  16  margin_of_error_area_median_income_householder_age_25_to_44_years  52 non-null     int64
#  17  estimated_area_median_income_householder_age_45_to_64_years        52 non-null     int64
#  18  margin_of_error_area_median_income_householder_age_45_to_64_years  52 non-null     int64
#  19  estimated_area_median_income_householder_age_65_and_over           52 non-null     int64
#  20  margin_of_error_area_median_income_householder_age_65_and_over     52 non-null     int64
#  21  percent_water                                                      52 non-null     float64
#  22  geometry                                                           52 non-null     geometry
# dtypes: float64(1), geometry(1), int64(12), object(9)
# memory usage: 9.5+ KB

# %%
fig, ax = plt.subplots(figsize=(14, 6))

gdf.plot(
    column="estimated_area_median_income_householder_age_65_and_over",
    figsize=(12, 12),
    alpha=0.5,
    edgecolor='k',
    legend=True,
    ax=ax
)

ax.set(title='Area Median Income for Householders Aged 65 and Over (ACS 2020 5-year)')

ax.legend(
    loc=(1, .5),
    fontsize=15,
    frameon=False
)

ax.set_axis_off()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Plots and charts

# %%
sns.boxplot(data=gdf, y = "estimated_area_median_income_householder_age_45_to_64_years")
# Out:
# <AxesSubplot:ylabel='estimated_area_median_income_householder_age_45_to_64_years'>
